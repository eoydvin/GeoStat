# %%
# %load_ext autoreload 
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
import pandas as pd
import os
import datetime
import pickle

def find_nearest(array, value):
    return (np.abs(array - value)).argmin(axis=1)

# %% [markdown]
# # Read and reformat data from FROST
# The data can be downloaded using get_weather_station.py

# %%
files = os.listdir('./stations')
files.remove('meta_data.pkl') #not a station

# %%
stations = []
for id_ in files:
    stations.append(xr.open_dataset("./stations/"+id_))

# %%
# string datatype was lost in export, this loop fixes these strings. 
for station in stations:
    station['id'] = station['id'].astype(str)
    station['name'] = station['name'].astype(str)
    station['shortname'] = station['shortname'].astype(str)
    station['latitude'] = float(station['latitude'])
    station['longitude'] = float(station['longitude'])
    station['resolution'] = station['resolution'].astype(str)

# %% [markdown]
# # Interpolate and plot map

# %%
# get grid from radar image
a_file = open("/home/erlend/radar.pkl", "rb")
output = pickle.load(a_file)
x_grid = output.pop('lon')
y_grid = output.pop('lat')

# %%
map_norway = np.zeros(x_grid.shape)
from global_land_mask import globe
for i in range(map_norway.shape[0]):
    for j in range(map_norway.shape[1]):
        map_norway[i, j] = globe.is_land(y_grid[i, j], x_grid[i, j])

# %%
#import pyresample

# Define lat-lon grid
#lon_grid, lat_grid = np.meshgrid(lon, lat)
#grid = pyresample.geometry.GridDefinition(lats=lat_grid, lons=lon_grid)

# Generate some random data on the grid
#data_grid = np.random.rand(lon_grid.shape[0], lon_grid.shape[1])

# Define some sample points
#my_lons = np.array([34.5, 36.5, 38.5])
#my_lats = np.array([12.0, 14.0, 16.0])
#swath = pyresample.geometry.SwathDefinition(lons=my_lons, lats=my_lats)

# %% [markdown]
# ### Kriging interpolation

# %%
from geostat import OrdinaryKriging # my own module

for t_i in range(len(stations[0]['time'])): # go thru recorded time    
    t = stations[0]['time'][t_i] # first station has all 7 timeintervalls
    
    # search if time value exists in station
    
    x_data = np.array([stat['longitude'] for stat in stations if t.isin(stat.time)])
    y_data = np.array([stat['latitude'] for stat in stations if t.isin(stat.time)])
    p_data = np.array([stat['PT1H'].sel(time = t) for stat in stations if t.isin(stat.time)])
        
    OK = OrdinaryKriging(
        x_data, #x-values
        y_data, #y-values
        p_data, #
        variogram_parameters = [-3, 1, 2, 0], # [alpha, beta, hr, c0]
        enable_plotting=True, 
        n_bins = 300, # number of averaging bins
    )    
    
    z_grid_intp, z_grid_sigma = OK.predict(x_grid, y_grid)
    plt.imshow(z_grid_intp) 
    plt.clim(0,6)
    plt.colorbar()

    plt.imshow(map_norway, alpha=0.1, cmap='gray')
    
    plt.title("Precipitation: " + np.datetime_as_string(stations[0].time.values[t_i])[0:16])

    # plt.scatter(index_array_2d[0], index_array_2d[1], c='red', marker='o')
    plt.show()
    
    
    #plt.imshow(z_grid_sigma, extent=[x_grid.min(), x_grid.max(), y_grid.min(), y_grid.max()],
    #       vmin=z_grid_intp.min(), vmax=z_grid_intp.max())
    #plt.clim(0,1.5)
    #plt.colorbar()
    #plt.title("Standard deviation: " + np.datetime_as_string(stations[0].time.values[t_i])[0:16])
    #plt.scatter(x_data, y_data, c='red', marker='o')
    #plt.show()

# %% [markdown]
# ### Verify by pykrige

# %%
# note: The variogram was found differently, here by 

sill_list = [1.0, 0.2, 1.2, 3.5, 0.6, 0.025, 0.004]

from pykrige.ok import OrdinaryKriging as pykrige
for t_i in range(len(stations[0]['time'])): # time index
    p = p_data[:, t_i]
    OK = pykrige(
        x_data, #x-values
        y_data, #y-values
        p, # precipitation
        variogram_model="gaussian",
        variogram_parameters = {'sill':sill_list[t_i], 'range':0.4, 'nugget':0},
        enable_plotting=True, 
        nlags = 3, #number of averaging bins
        pseudo_inv = True
    )
    
    z_grid_intp, z_grid_sigma = OK.execute("grid", x_grid, y_grid)
    z_grid_sigma = np.sqrt(z_grid_sigma)
    plt.imshow(z_grid_intp, extent=[x_grid.min(), x_grid.max(), y_grid.min(), y_grid.max()],
           vmin=z_grid_intp.min(), vmax=z_grid_intp.max())
    plt.clim(0,5)
    plt.colorbar()
    
    plt.title("Precipitation: " + stations[0].time.values[t_i][0:16])
    plt.scatter(x_data, y_data, c='red', marker='o')
    plt.show()
    
    
    plt.imshow(z_grid_sigma, extent=[x_grid.min(), x_grid.max(), y_grid.min(), y_grid.max()],
           vmin=z_grid_intp.min(), vmax=z_grid_intp.max())
    plt.clim(0,1.5)
    plt.colorbar()
    plt.title("Standard deviation: " + stations[0].time.values[t_i][0:16])
    plt.scatter(x_data, y_data, c='red', marker='o')
    plt.show()

# %%
p_data
# Out:
# [<xarray.DataArray 'PT1H' (time: 7)>
#  array([0. , 0.2, 0. , 0. , 0. , 0. , 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.66
#      longitude   float64 5.954
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U5 'Etne '
#      id          <U7 'SN47498'
#      name        <U7 'ETNE II',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0, 0, 0, 0, 0, 0, 0])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 60.34
#      longitude   float64 6.218
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U8 'Aksneset'
#      id          <U7 'SN50110'
#      name        <U15 'KVAM - AKSNESET',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0. , 0. , 0. , 0. , 0. , 0. , 1.4])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 60.29
#      longitude   float64 5.278
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U7 'Sandsli'
#      id          <U7 'SN50480'
#      name        <U16 'BERGEN - SANDSLI',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0.1, 0.3, 0.2, 0.3, 1.2, 0.3, 0.8])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 62.13
#      longitude   float64 9.995
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U8 'Folldal '
#      id          <U6 'SN9160'
#      name        <U18 'FOLLDAL - FREDHEIM',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0, 0, 0, 0, 0, 0, 0])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.39
#      longitude   float64 5.264
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U10 'Storasund '
#      id          <U7 'SN47262'
#      name        <U18 'KARMØY - STORASUND',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0. , 0.4, 0. , 0. , 0.2, 0.2, 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.39
#      longitude   float64 11.39
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U9 'Rakkestad'
#      id          <U6 'SN3290'
#      name        <U9 'RAKKESTAD',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0.5, 4.3, 1.8, 0. , 0. , 0. , 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 60.26
#      longitude   float64 8.706
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U15 'Uvdal kraftverk'
#      id          <U7 'SN29350'
#      name        <U15 'UVDAL KRAFTVERK',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0.6, 1.3, 0.3, 0. , 0. , 0. , 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.05
#      longitude   float64 9.701
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U6 'Brevik'
#      id          <U7 'SN30248'
#      name        <U6 'BREVIK',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0, 0, 0, 0, 0, 0, 0])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 63.94
#      longitude   float64 11.43
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U4 'Mære'
#      id          <U7 'SN70680'
#      name        <U8 'MÆRE III',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0.8, 1.4, 3.8, 0.8, 0.4, 0.2, 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.6
#      longitude   float64 10.4
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U14 'Svelvik - Knem'
#      id          <U7 'SN26950'
#      name        <U14 'SVELVIK - KNEM',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0, 0, 0, 0, 0, 0, 0])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.26
#      longitude   float64 5.196
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U5 'Åkra '
#      id          <U7 'SN47230'
#      name        <U17 'ÅKRA UNGDOMSSKOLE',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0, 0, 0, 0, 0, 0, 0])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 62.72
#      longitude   float64 8.775
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U10 'Innerdalen'
#      id          <U7 'SN64700'
#      name        <U10 'INNERDALEN',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0, 0, 0, 0, 0, 0, 0])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.26
#      longitude   float64 5.193
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U9 'Åkrehamn '
#      id          <U7 'SN47232'
#      name        <U13 'ÅKREHAMN AMFI',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([4.4, 3.2, 0.2, 0.9, 0.8, 1.2, 0.8])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.81
#      longitude   float64 7.214
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U12 'Haukeliseter'
#      id          <U7 'SN33950'
#      name        <U21 'HAUKELISETER TESTFELT',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0. , 0. , 4.2, 2.7, 0.9, 0. , 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 61.15
#      longitude   float64 10.45
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U10 'Bjørnerud '
#      id          <U7 'SN12980'
#      name        <U23 'LILLEHAMMER - BJØRNERUD',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0. , 0.4, 1.4, 2.3, 0.2, 0. , 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 60.82
#      longitude   float64 11.07
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U17 'Hamar − Stavsberg'
#      id          <U7 'SN12320'
#      name        <U17 'HAMAR - STAVSBERG',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0.4, 0.4, 1.3, 0.1, 0. , 0. , 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.75
#      longitude   float64 10.23
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U16 'Bragernes skole '
#      id          <U7 'SN26852'
#      name        <U25 'DRAMMEN - BRAGERNES SKOLE',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([2.5, 0.4, 0.2, 0. , 0. , 0. , 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 58.69
#      longitude   float64 7.803
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U14 'Byglandsfjord '
#      id          <U7 'SN39750'
#      name        <U21 'BYGLANDSFJORD - NESET',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0.3, 0.6, 0.5, 0.6, 0.3, 0.1, 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.73
#      longitude   float64 10.21
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U11 'Bangeløkka '
#      id          <U7 'SN26580'
#      name        <U20 'DRAMMEN - BANGELØKKA',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0.6, 0.4, 1.2, 0. , 0. , 0. , 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.79
#      longitude   float64 10.26
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U4 'Lier'
#      id          <U7 'SN19940'
#      name        <U4 'LIER',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([1.8, 1.7, 0.8, 1.3, 0.5, 0.3, 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.22
#      longitude   float64 10.41
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U8 'Borgheim'
#      id          <U7 'SN27460'
#      name        <U19 'NØTTERØY - BORGHEIM',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0.3, 1.1, 1.3, 2.2, 0.8, 0.5, 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.94
#      longitude   float64 10.9
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U8 'Furuset '
#      id          <U7 'SN18235'
#      name        <U14 'OSLO - FURUSET',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0. , 1.2, 2. , 0.4, 0. , 0. , 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 60.14
#      longitude   float64 10.27
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U7 'Hverven'
#      id          <U7 'SN20280'
#      name        <U18 'HØNEFOSS - HVERVEN',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([3. , 0.5, 0. , 0. , 0. , 0. , 0.1])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.03
#      longitude   float64 8.519
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U9 'Tveitsund'
#      id          <U7 'SN37230'
#      name        <U9 'TVEITSUND',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0. , 0. , 0.7, 1.5, 0.2, 0. , 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 60.8
#      longitude   float64 11.1
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U13 'Hamar (Disen)'
#      id          <U7 'SN12290'
#      name        <U8 'HAMAR II',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([1.5, 0.4, 0. , 0. , 0. , 0. , 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 58.46
#      longitude   float64 8.765
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U16 'Arendal sentrum '
#      id          <U7 'SN36055'
#      name        <U15 'ARENDAL SENTRUM',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([2.1, 1.5, 0.9, 2. , 1. , 0.2, 0.1])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.67
#      longitude   float64 10.81
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U12 'Rustadskogen'
#      id          <U7 'SN17870'
#      name        <U17 'ÅS - RUSTADSKOGEN',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0. , 0. , 0. , 0. , 0.3, 0. , 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 62.22
#      longitude   float64 9.542
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U8 'Hjerkinn'
#      id          <U6 'SN9310'
#      name        <U11 'HJERKINN II',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0, 0, 0, 0, 0, 0, 0])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 60.38
#      longitude   float64 5.542
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U12 'Gullfjellet '
#      id          <U7 'SN50865'
#      name        <U11 'GULLFJELLET',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([1.2, 1.4, 1. , 1.3, 0.8, 0.4, 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.28
#      longitude   float64 10.43
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U16 'Tønsberg (Kilen)'
#      id          <U7 'SN27270'
#      name        <U16 'TØNSBERG - KILEN',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0.1, 0.8, 1.5, 2.7, 0.5, 0.1, 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.93
#      longitude   float64 10.79
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U6 'Løren '
#      id          <U7 'SN18205'
#      name        <U12 'OSLO - LØREN',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0.1, 0. , 0.3, 0.6, 0.2, 0.1, 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 58.96
#      longitude   float64 5.728
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U6 'Våland'
#      id          <U7 'SN44640'
#      name        <U18 'STAVANGER - VÅLAND',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0. , 0. , 0. , 0. , 0. , 0. , 2.3])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 60.4
#      longitude   float64 5.336
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U13 'Skredderdalen'
#      id          <U7 'SN50570'
#      name        <U13 'SKREDDERDALEN',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0.7, 0.5, 1.7, 0.1, 0. , 0. , 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.74
#      longitude   float64 10.23
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U15 'Drammen Sletta '
#      id          <U7 'SN26590'
#      name        <U16 'DRAMMEN - SLETTA',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0, 0, 0, 0, 0, 0, 0])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.15
#      longitude   float64 5.26
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U15 'Steiningsholmen'
#      id          <U7 'SN47192'
#      name        <U17 'SKUDENES INDUSTRI',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0.5, 0.3, 1.9, 0. , 0. , 0. , 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.09
#      longitude   float64 9.802
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U10 'Langangen '
#      id          <U7 'SN30249'
#      name        <U9 'LANGANGEN',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0. , 0. , 0. , 0. , 0. , 0. , 0.3])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 63.4
#      longitude   float64 10.42
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U9 'Risvollan'
#      id          <U7 'SN68230'
#      name        <U21 'TRONDHEIM - RISVOLLAN',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([1. , 0.8, 0.2, 0.4, 1. , 0.9, 0.1])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.65
#      longitude   float64 6.35
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U5 'Sauda'
#      id          <U7 'SN46610'
#      name        <U5 'SAUDA',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0.4, 1.4, 1.2, 2.6, 1. , 0.2, 0.1])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.88
#      longitude   float64 10.82
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U12 'Lambertseter'
#      id          <U7 'SN18020'
#      name        <U19 'OSLO - LAMBERTSETER',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0. , 3.7, 3.2, 0.1, 2.1, 0.8, 0.7])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 60.59
#      longitude   float64 7.527
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U5 'Finse'
#      id          <U7 'SN25830'
#      name        <U9 'FINSEVATN',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0.9, 1. , 0.9, 2.3, 1.4, 0.2, 0.1])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.84
#      longitude   float64 10.82
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U11 'Ljabruveien'
#      id          <U7 'SN17980'
#      name        <U18 'OSLO - LJABRUVEIEN',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([1.6, 0.9, 1.7, 4.3, 1.1, 0.4, 0.1])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.55
#      longitude   float64 10.58
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U6 'Tofte '
#      id          <U7 'SN19825'
#      name        <U15 'TOFTE - RULLETO',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0. , 0. , 0.1, 0. , 0. , 0.5, 0.3])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 61.1
#      longitude   float64 7.503
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U6 'Lærdal'
#      id          <U7 'SN54110'
#      name        <U9 'LÆRDAL IV',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0.6, 1.5, 1.4, 1.4, 0.3, 0.3, 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.23
#      longitude   float64 10.35
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U6 'Melsom'
#      id          <U7 'SN27450'
#      name        <U6 'MELSOM',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0.1, 0.9, 1.4, 1.5, 2. , 1.4, 0.6])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 60.39
#      longitude   float64 11.56
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U9 'Nord-Odal'
#      id          <U6 'SN5350'
#      name        <U9 'NORD-ODAL',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0.1, 0. , 0.1, 0.1, 0. , 1. , 0.4])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 62.95
#      longitude   float64 10.18
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U8 'Soknedal'
#      id          <U7 'SN67280'
#      name        <U8 'SOKNEDAL',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([1. , 3.3, 2.2, 0.1, 0. , 0.2, 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.13
#      longitude   float64 10.22
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U11 'Sandefjord '
#      id          <U7 'SN27590'
#      name        <U20 'SANDEFJORD - SENTRUM',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0. , 0.3, 0.8, 0.6, 0.1, 0. , 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 60.77
#      longitude   float64 10.81
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U15 'Kise på Hedmark'
#      id          <U7 'SN12550'
#      name        <U15 'KISE PA HEDMARK',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0. , 0.1, 0.9, 0.3, 0.7, 0. , 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 58.73
#      longitude   float64 5.726
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U4 'Time'
#      id          <U7 'SN44190'
#      name        <U10 'TIME - LYE',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([1.3, 1. , 0.3, 1.6, 0.2, 0.2, 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.4
#      longitude   float64 10.75
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U8 'Huggenes'
#      id          <U7 'SN17380'
#      name        <U16 'RYGGE - HUGGENES',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0, 0, 0, 0, 0, 0, 0])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 62.74
#      longitude   float64 7.228
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U17 'Molde − Nøisomhed'
#      id          <U7 'SN62290'
#      name        <U17 'MOLDE - NØISOMHED',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([1.1, 0.3, 0.4, 0. , 0. , 0. , 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.73
#      longitude   float64 9.873
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U11 'Vestfossen '
#      id          <U7 'SN26630'
#      name        <U10 'VESTFOSSEN',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0.5, 0.8, 2.2, 1.8, 0. , 0. , 0.1])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.92
#      longitude   float64 10.59
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U8 'Nadderud'
#      id          <U7 'SN19458'
#      name        <U8 'NADDERUD',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0.5, 0.2, 0. , 0.7, 0. , 0.1, 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.04
#      longitude   float64 11.03
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U7 'HVALER '
#      id          <U6 'SN1070'
#      name        <U15 'HVALER - BREKKE',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0.8, 1. , 0.4, 0.9, 1.1, 0.4, 0.2])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 60.13
#      longitude   float64 6.629
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U10 'Skjeggedal'
#      id          <U7 'SN49420'
#      name        <U10 'SKJEGGEDAL',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0, 0, 0, 0, 0, 0, 0])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 58.18
#      longitude   float64 8.091
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U6 'Hånes '
#      id          <U7 'SN39030'
#      name        <U20 'KRISTIANSAND - HÅNES',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0. , 0.3, 0.1, 0.1, 0. , 0. , 0.1])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.75
#      longitude   float64 10.2
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U16 'Drammen sykehus '
#      id          <U7 'SN26864'
#      name        <U15 'DRAMMEN SYKEHUS',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0. , 0. , 0. , 0.2, 0.6, 0.4, 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 62.11
#      longitude   float64 10.63
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U7 'Alvdal '
#      id          <U6 'SN8880'
#      name        <U6 'ALVDAL',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0. , 0. , 0. , 0. , 0. , 0. , 0.9])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 60.47
#      longitude   float64 5.342
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U5 'Åsane'
#      id          <U7 'SN50810'
#      name        <U5 'ÅSANE',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0, 0, 0, 0, 0, 0, 0])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 62.48
#      longitude   float64 6.817
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U6 'Ørskog'
#      id          <U7 'SN60800'
#      name        <U6 'ØRSKOG',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([1.3, 0. , 0. , 0. , 0. , 0. , 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 58.6
#      longitude   float64 8.417
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U10 'Hynnekleiv'
#      id          <U7 'SN38730'
#      name        <U10 'HYNNEKLEIV',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0. , 0. , 0. , 0.1, 0.4, 0. , 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 58.11
#      longitude   float64 6.567
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U9 'Lista fyr'
#      id          <U7 'SN42160'
#      name        <U9 'LISTA FYR',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0. , 0. , 0.4, 0.3, 0.4, 0. , 0.1])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 58.66
#      longitude   float64 5.555
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U12 'Obrestad fyr'
#      id          <U7 'SN44080'
#      name        <U12 'OBRESTAD FYR',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0, 0, 0, 0, 0, 0, 0])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 63.42
#      longitude   float64 10.35
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U11 'Sverresborg'
#      id          <U7 'SN68125'
#      name        <U11 'SVERRESBORG',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0. , 0. , 3.4, 2.6, 1.8, 0. , 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 61.22
#      longitude   float64 10.26
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U7 'Follebu'
#      id          <U7 'SN13030'
#      name        <U17 'GAUSDAL - FOLLEBU',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0.8, 1. , 4.6, 0.2, 0. , 0.2, 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.38
#      longitude   float64 10.24
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U14 'Ramnes (Kile) '
#      id          <U7 'SN27315'
#      name        <U20 'RAMNES - KILE VESTRE',
#  <xarray.DataArray 'PT1H' (time: 5)>
#  array([0.1, 0.5, 0.3, 0.2, 0.1])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T13:0...
#      latitude    float64 58.93
#      longitude   float64 5.69
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U11 'Ullandhaug '
#      id          <U7 'SN44562'
#      name        <U10 'ULLANDHAUG',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0. , 0. , 0. , 0. , 0. , 0.3, 0.5])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 61.77
#      longitude   float64 5.298
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U7 'Svelgen'
#      id          <U7 'SN57810'
#      name        <U10 'SVELGEN II',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0, 0, 0, 0, 0, 0, 0])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 63.52
#      longitude   float64 9.113
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U6 'Hitra '
#      id          <U7 'SN65451'
#      name        <U19 'HITRA - SANDSTAD II',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0. , 0. , 4.3, 2.8, 0.8, 0. , 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 61.14
#      longitude   float64 10.51
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U15 'Nordsetervegen '
#      id          <U7 'SN12710'
#      name        <U41 'LILLEHAMMER - NORDSETERVEGEN HØYDEBASSENG',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0, 0, 0, 0, 0, 0, 0])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 62.02
#      longitude   float64 7.664
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U6 'Grotli'
#      id          <U7 'SN15890'
#      name        <U10 'GROTLI III',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0. , 0. , 0. , 0. , 0. , 0.1, 0.3])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 63.41
#      longitude   float64 10.45
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U16 'Trondheim − Voll'
#      id          <U7 'SN68860'
#      name        <U16 'TRONDHEIM - VOLL',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0. , 0. , 2.1, 2.4, 0.2, 0. , 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.86
#      longitude   float64 10.66
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U10 'Tangenåsen'
#      id          <U7 'SN17810'
#      name        <U21 'NESODDEN - TANGENÅSEN',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0. , 0. , 1. , 1. , 0.2, 0. , 0.2])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 60.8
#      longitude   float64 11.2
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U6 'Ilseng'
#      id          <U7 'SN12180'
#      name        <U6 'ILSENG',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0, 0, 0, 0, 0, 0, 0])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.38
#      longitude   float64 5.311
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U8 'Norheim '
#      id          <U7 'SN47170'
#      name        <U7 'NORHEIM',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0.5, 0.4, 1.7, 0. , 0. , 0. , 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.73
#      longitude   float64 10.03
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U4 'Åsen'
#      id          <U7 'SN26802'
#      name        <U16 'MJØNDALEN - ÅSEN',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0.3, 0.4, 0.8, 0.1, 0. , 0. , 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.73
#      longitude   float64 10.2
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U7 'Danvik '
#      id          <U7 'SN26594'
#      name        <U16 'DRAMMEN - DANVIK',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0.3, 0.8, 1.9, 2.4, 0.2, 0. , 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.89
#      longitude   float64 10.61
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U8 'Storøya '
#      id          <U7 'SN19405'
#      name        <U15 'BÆRUM - STORØYA',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0. , 0.6, 1.4, 2.9, 1.5, 0.5, 0.6])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 60.39
#      longitude   float64 11.23
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U10 'Minnesund '
#      id          <U7 'SN11450'
#      name        <U25 'MINNESUND JERNBANESTASJON',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0, 0, 0, 0, 0, 0, 0])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 62.26
#      longitude   float64 8.2
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U6 'Bjorli'
#      id          <U7 'SN61630'
#      name        <U6 'BJORLI',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([1.3, 0.5, 0.9, 0. , 0. , 0. , 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.77
#      longitude   float64 9.915
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U15 'Hokksund - Loe '
#      id          <U7 'SN26810'
#      name        <U14 'HOKKSUND - LOE',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([3.2, 2.5, 0.8, 0. , 0. , 0. , 1.1])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.84
#      longitude   float64 8.178
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U9 'Møsstrand'
#      id          <U7 'SN31620'
#      name        <U12 'MØSSTRAND II',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0, 0, 0, 0, 0, 0, 1])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.31
#      longitude   float64 4.872
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U6 'Utsira'
#      id          <U7 'SN47300'
#      name        <U10 'UTSIRA FYR',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0.2, 0.8, 1.9, 3.2, 0.4, 0.1, 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.9
#      longitude   float64 10.68
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U6 'Bygdøy'
#      id          <U7 'SN18815'
#      name        <U13 'OSLO - BYGDØY',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0, 0, 0, 0, 0, 0, 0])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 62.16
#      longitude   float64 6.288
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U11 'Eitrefjell '
#      id          <U7 'SN59695'
#      name        <U18 'ØRSTA - EITREFJELL',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0, 0, 0, 0, 0, 0, 0])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 62.99
#      longitude   float64 8.69
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U5 'Sylte'
#      id          <U7 'SN64760'
#      name        <U16 'SURNADAL - SYLTE',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0.9, 1.2, 2.5, 2.2, 1.4, 0.8, 0.1])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.95
#      longitude   float64 10.98
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U9 'Haneborg '
#      id          <U6 'SN4110'
#      name        <U20 'LØRENSKOG - HANEBORG',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0. , 0. , 0. , 0. , 0.9, 0. , 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 62.45
#      longitude   float64 9.583
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U9 'Drivdalen'
#      id          <U7 'SN63820'
#      name        <U9 'DRIVDALEN',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0.2, 0.4, 0. , 0.4, 0.3, 0.2, 0.1])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.32
#      longitude   float64 11.04
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U6 'Øsaker'
#      id          <U6 'SN3370'
#      name        <U6 'ØSAKER',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0.3, 1.1, 1.4, 2.3, 0.9, 0.4, 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.97
#      longitude   float64 10.92
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U6 'Vestli'
#      id          <U7 'SN18270'
#      name        <U13 'OSLO - VESTLI',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0.8, 1.1, 2.1, 0.5, 1.7, 1. , 0.6])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 60.13
#      longitude   float64 11.39
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U5 'Årnes'
#      id          <U6 'SN4920'
#      name        <U5 'ÅRNES',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0. , 0.9, 0.7, 0. , 0. , 0.3, 0.2])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 60.66
#      longitude   float64 7.276
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U9 'Midtstova'
#      id          <U7 'SN53530'
#      name        <U9 'MIDTSTOVA',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0.3, 0.5, 0.9, 0. , 0. , 0. , 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.75
#      longitude   float64 10.17
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U11 'Øren skole '
#      id          <U7 'SN26872'
#      name        <U20 'DRAMMEN - ØREN SKOLE',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0. , 0. , 0. , 0. , 0. , 0.7, 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 62.76
#      longitude   float64 7.209
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U11 'Hindalsrøra'
#      id          <U7 'SN62295'
#      name        <U19 'MOLDE - HINDALSRØRA',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0. , 0. , 0. , 1.2, 1.1, 4.3, 2. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 61.03
#      longitude   float64 5.381
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U5 'Takle'
#      id          <U7 'SN52860'
#      name        <U5 'TAKLE',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0.9, 2.6, 1.2, 0.5, 0.1, 0.2, 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.13
#      longitude   float64 10.26
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U8 'Gjekstad'
#      id          <U7 'SN27540'
#      name        <U21 'SANDEFJORD - GJEKSTAD',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0, 0, 0, 0, 0, 0, 3])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 60.38
#      longitude   float64 5.332
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U13 'Bergen (UiB) '
#      id          <U7 'SN50539'
#      name        <U20 'BERGEN - FLORIDA UIB',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([1.3, 1.7, 0.4, 1.1, 0.3, 0.2, 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.21
#      longitude   float64 10.45
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U9 'Knarrberg'
#      id          <U7 'SN27403'
#      name        <U20 'NØTTERØY - KNARRBERG',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0. , 0. , 0. , 0. , 0. , 0. , 0.2])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 63.49
#      longitude   float64 10.88
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U9 'Kvithamar'
#      id          <U7 'SN69150'
#      name        <U9 'KVITHAMAR',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0.3, 0.4, 0.1, 0. , 0. , 0.1, 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.49
#      longitude   float64 5.721
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U17 'Vats i Vindafjord'
#      id          <U7 'SN46930'
#      name        <U17 'VATS I VINDAFJORD',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0. , 0. , 0. , 0.1, 0.1, 0. , 0.5])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 61.29
#      longitude   float64 5.044
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U9 'Fureneset'
#      id          <U7 'SN56420'
#      name        <U9 'FURENESET',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0, 0, 0, 0, 0, 0, 0])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.15
#      longitude   float64 5.253
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U15 'Skudenes u.sk. '
#      id          <U7 'SN47194'
#      name        <U21 'SKUDENES UNGDOMSSKOLE',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0. , 0. , 0. , 0. , 0. , 0. , 2.5])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 60.38
#      longitude   float64 5.333
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U6 'Bergen'
#      id          <U7 'SN50540'
#      name        <U16 'BERGEN - FLORIDA',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0.3, 0.5, 1.9, 0.6, 0. , 0. , 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.86
#      longitude   float64 10.44
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U11 'Asker - Sem'
#      id          <U7 'SN19710'
#      name        <U5 'ASKER',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0.2, 0.8, 1.5, 3. , 0.4, 0. , 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.94
#      longitude   float64 10.72
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U15 'Oslo (Blindern)'
#      id          <U7 'SN18700'
#      name        <U15 'OSLO - BLINDERN',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0. , 0.7, 4.2, 3.5, 0.3, 0. , 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 60.93
#      longitude   float64 10.04
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U10 'Vest-Torpa'
#      id          <U7 'SN21680'
#      name        <U13 'VEST-TORPA II',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0. , 3.5, 1.3, 0.5, 0. , 0. , 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 60.57
#      longitude   float64 9.132
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U7 'Nesbyen'
#      id          <U7 'SN24890'
#      name        <U16 'NESBYEN - TODOKK',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0.1, 0.1, 0.1, 0. , 0.3, 0. , 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.06
#      longitude   float64 6.647
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U8 'Lysebotn'
#      id          <U7 'SN45350'
#      name        <U8 'LYSEBOTN',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0. , 0. , 0. , 0.2, 0. , 0.4, 0.3])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 61.65
#      longitude   float64 7.277
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U16 'Breheimsenteret '
#      id          <U7 'SN55420'
#      name        <U28 'JOSTEDALEN - BREHEIMSENTERET',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0. , 0. , 0. , 0. , 0. , 0.1, 0.2])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 63.36
#      longitude   float64 10.36
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U8 'Saupstad'
#      id          <U7 'SN68120'
#      name        <U8 'SAUPSTAD',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0. , 0. , 0. , 0. , 0. , 0. , 0.2])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 60.86
#      longitude   float64 5.973
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U7 'Modalen'
#      id          <U7 'SN52310'
#      name        <U11 'MODALEN III',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([1.2, 1. , 5.6, 0.2, 0. , 0.1, 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.15
#      longitude   float64 10.2
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U8 'Mosserød'
#      id          <U7 'SN27564'
#      name        <U21 'SANDEFJORD - MOSSERØD',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0.2, 0.6, 2.1, 1.9, 0.4, 0.1, 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.81
#      longitude   float64 10.63
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U12 'Blekslitjern'
#      id          <U7 'SN17780'
#      name        <U12 'BLEKSLITJERN',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0.7, 0.4, 1.5, 0. , 0. , 0. , 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.77
#      longitude   float64 10.06
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U9 'Olleveien'
#      id          <U7 'SN26780'
#      name        <U23 'SOLBERGELVA - OLLEVEIEN',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0.3, 0.5, 0.9, 0. , 0. , 0. , 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.74
#      longitude   float64 10.21
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U16 'Drammen tinghus '
#      id          <U7 'SN26862'
#      name        <U15 'DRAMMEN TINGHUS',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([2.7, 1.1, 1.4, 1.4, 3.3, 0.9, 0.4])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.83
#      longitude   float64 6.733
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U14 'Røldalsfjellet'
#      id          <U7 'SN46430'
#      name        <U14 'RØLDALSFJELLET',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0. , 0.1, 6.6, 1.3, 0.5, 0. , 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 61.12
#      longitude   float64 9.063
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U13 'Løken i Volbu'
#      id          <U7 'SN23500'
#      name        <U13 'LØKEN I VOLBU',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0.1, 1. , 1.6, 2.6, 0.6, 0. , 0.1])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.92
#      longitude   float64 10.8
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U5 'Hovin'
#      id          <U7 'SN18210'
#      name        <U12 'OSLO - HOVIN',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0.6, 0.3, 1.3, 0.1, 0. , 0. , 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.72
#      longitude   float64 10.22
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U7 'Austad '
#      id          <U7 'SN26932'
#      name        <U16 'DRAMMEN - AUSTAD',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([3.4, 2.2, 0.1, 0. , 0. , 0. , 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.38
#      longitude   float64 9.213
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U5 'Gvarv'
#      id          <U7 'SN32060'
#      name        <U11 'GVARV - NES',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([1.1, 0.8, 0.4, 0.1, 0. , 0. , 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.12
#      longitude   float64 9.649
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U10 'Klevstrand'
#      id          <U7 'SN30258'
#      name        <U22 'PORSGRUNN - KLEVSTRAND',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0.6, 0.3, 1.8, 0. , 0. , 0. , 0. ])
#  Coordinates:
# ...
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U15 'Sandnes − Rovik'
#      id          <U7 'SN44730'
#      name        <U15 'SANDNES - ROVIK',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0, 0, 0, 0, 0, 0, 0])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 62.3
#      longitude   float64 7.253
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U8 'Valldal '
#      id          <U7 'SN60640'
#      name        <U14 'VALLDAL - MURI',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0.1, 1.3, 1.5, 2.7, 0.6, 0.1, 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.95
#      longitude   float64 10.83
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U11 'Tonsenhagen'
#      id          <U7 'SN18225'
#      name        <U18 'OSLO - TONSENHAGEN',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0, 0, 0, 0, 0, 0, 0])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 62.47
#      longitude   float64 6.211
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U7 'Ålesund'
#      id          <U7 'SN60945'
#      name        <U10 'ÅLESUND IV',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0. , 0.7, 1.3, 3.6, 1.3, 0.1, 0.3])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 60.21
#      longitude   float64 11.08
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U14 'Gardermoen PLU'
#      id          <U6 'SN4785'
#      name        <U14 'GARDERMOEN PLU',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0. , 0. , 0. , 0.2, 0. , 0. , 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 62.02
#      longitude   float64 9.214
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U7 'Lannem '
#      id          <U7 'SN16400'
#      name        <U12 'DOVRE-LANNEM',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0.5, 1.2, 1.7, 2.6, 1.1, 1. , 0.1])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.95
#      longitude   float64 10.93
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U9 'Høybråten'
#      id          <U7 'SN18260'
#      name        <U16 'OSLO - HØYBRÅTEN',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([1.4, 0.3, 2.7, 0. , 0. , 0. , 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.71
#      longitude   float64 10.27
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U12 'Solumstrand '
#      id          <U7 'SN26934'
#      name        <U21 'DRAMMEN - SOLUMSTRAND',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0.1, 0.8, 1.8, 2.7, 0.5, 0. , 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.94
#      longitude   float64 10.75
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U7 'Bjølsen'
#      id          <U7 'SN18390'
#      name        <U14 'OSLO - BJØLSEN',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0, 0, 0, 0, 0, 0, 0])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 62.56
#      longitude   float64 7.672
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U9 'Åndalsnes'
#      id          <U7 'SN61340'
#      name        <U22 'ÅNDALSNES - KAMSHAUGEN',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([1.1, 1.8, 0.2, 0.9, 0.2, 0.1, 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.12
#      longitude   float64 10.4
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U5 'Tjøme'
#      id          <U7 'SN27420'
#      name        <U5 'TJØME',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0.2, 0.7, 1.9, 2.8, 0.4, 0. , 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.91
#      longitude   float64 10.72
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U11 'Solli plass'
#      id          <U7 'SN18645'
#      name        <U18 'OSLO - SOLLI PLASS',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0, 0, 0, 0, 0, 0, 0])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 62.23
#      longitude   float64 7.422
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U7 'Tafjord'
#      id          <U7 'SN60500'
#      name        <U7 'TAFJORD',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0.4, 1.1, 2.1, 2.9, 0.2, 0. , 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.98
#      longitude   float64 10.67
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U13 'Tryvannshøgda'
#      id          <U7 'SN18950'
#      name        <U13 'TRYVANNSHØGDA',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0, 0, 0, 0, 0, 0, 0])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 62.91
#      longitude   float64 8.186
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U8 'Tingvoll'
#      id          <U7 'SN64510'
#      name        <U8 'TINGVOLL',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0. , 0.6, 1. , 2.2, 0. , 0. , 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 60.7
#      longitude   float64 10.87
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U9 'Apelsvoll'
#      id          <U7 'SN11500'
#      name        <U23 'ØSTRE TOTEN - APELSVOLL',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0.3, 1.2, 1.9, 2.9, 0.3, 0. , 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.92
#      longitude   float64 10.63
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U9 'Lilleaker'
#      id          <U7 'SN18980'
#      name        <U16 'OSLO - LILLEAKER',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0. , 0. , 5. , 2.8, 0.6, 0. , 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 61.1
#      longitude   float64 10.51
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U15 'Vårsætergrenda '
#      id          <U7 'SN12700'
#      name        <U28 'LILLEHAMMER - VÅRSÆTERGRENDA',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0. , 0. , 0. , 0. , 0.1, 0. , 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 62.6
#      longitude   float64 9.667
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U6 'Oppdal'
#      id          <U7 'SN63705'
#      name        <U14 'OPPDAL - SÆTER',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0. , 0. , 1.5, 3.7, 1.1, 0. , 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 61.46
#      longitude   float64 10.19
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U6 'Fåvang'
#      id          <U7 'SN13150'
#      name        <U6 'FÅVANG',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0.4, 0.3, 0.7, 1.7, 0.4, 0.1, 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.05
#      longitude   float64 6.121
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U8 'Liarvatn'
#      id          <U7 'SN45530'
#      name        <U8 'LIARVATN',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([1.9, 0.9, 0.3, 0. , 0. , 0. , 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.14
#      longitude   float64 9.639
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U9 'Porsgrunn'
#      id          <U7 'SN30261'
#      name        <U9 'PORSGRUNN',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([1.5, 4.2, 2.7, 0.2, 0. , 0. , 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 60.14
#      longitude   float64 9.439
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U14 'Nedre Eggedal '
#      id          <U7 'SN26350'
#      name        <U22 'SIGDAL - NEDRE EGGEDAL',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0.5, 0.5, 0.7, 0. , 0. , 0. , 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.75
#      longitude   float64 10.14
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U8 'Åssiden '
#      id          <U7 'SN26898'
#      name        <U17 'DRAMMEN - ÅSSIDEN',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0.1, 1. , 1.6, 3.1, 0.4, 0. , 0.1])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.94
#      longitude   float64 10.72
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U12 'Blindern PLU'
#      id          <U7 'SN18701'
#      name        <U19 'OSLO - BLINDERN PLU',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0.2, 0. , 0. , 0. , 0. , 0. , 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 58.2
#      longitude   float64 8.077
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U6 'Kjevik'
#      id          <U7 'SN39040'
#      name        <U6 'KJEVIK',
#  <xarray.DataArray 'PT1H' (time: 6)>
#  array([0. , 1. , 1.5, 4.5, 0.7, 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T13:0...
#      latitude    float64 60.12
#      longitude   float64 10.83
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U7 'Hakadal'
#      id          <U6 'SN4460'
#      name        <U23 'HAKADAL JERNBANESTASJON',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0. , 0. , 0. , 1. , 0.2, 0. , 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 61.72
#      longitude   float64 9.154
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U10 'Leirflaten'
#      id          <U7 'SN14200'
#      name        <U10 'LEIRFLATEN',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0.2, 0. , 0.2, 0. , 0. , 0. , 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 58.13
#      longitude   float64 7.045
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U7 'Lyngdal'
#      id          <U7 'SN41825'
#      name        <U7 'LYNGDAL',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0, 0, 0, 0, 0, 0, 0])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 58.15
#      longitude   float64 7.997
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U11 'Kvadraturen'
#      id          <U7 'SN39200'
#      name        <U26 'KRISTIANSAND - KVADRATUREN',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0.8, 1.4, 1.8, 2.6, 1.2, 1.2, 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.98
#      longitude   float64 10.98
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U8 'Skjetten'
#      id          <U6 'SN4260'
#      name        <U18 'SKEDSMO - HELLERUD',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0.2, 1.1, 1.2, 2.6, 0.8, 0.1, 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.97
#      longitude   float64 10.87
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U7 'Ammerud'
#      id          <U7 'SN18245'
#      name        <U14 'OSLO - AMMERUD',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0. , 0. , 0. , 0. , 0. , 0. , 4.3])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 60.02
#      longitude   float64 5.204
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U10 'Austevoll '
#      id          <U7 'SN50175'
#      name        <U9 'AUSTEVOLL',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([1.7, 1.5, 0.5, 1.4, 0.6, 0.2, 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.24
#      longitude   float64 10.46
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U8 'Føynland'
#      id          <U7 'SN27400'
#      name        <U19 'NØTTERØY - FØYNLAND',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0, 0, 0, 0, 0, 0, 0])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 61.42
#      longitude   float64 6.376
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U10 'Haukedalen'
#      id          <U7 'SN56960'
#      name        <U8 'HAUKEDAL',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0. , 0. , 0. , 3.7, 2.6, 0.1, 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 61.89
#      longitude   float64 9.48
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U9 'Høvringen'
#      id          <U7 'SN16271'
#      name        <U12 'HØVRINGEN II',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0. , 0.2, 4.6, 2.8, 0.7, 0. , 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 61.11
#      longitude   float64 10.47
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U9 'Rådhuset '
#      id          <U7 'SN12648'
#      name        <U22 'LILLEHAMMER - RÅDHUSET',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0.5, 0.8, 0.8, 0.8, 0. , 0. , 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 60.0
#      longitude   float64 10.46
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U8 'Aurevann'
#      id          <U7 'SN19530'
#      name        <U8 'AUREVANN',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0.8, 3. , 1.4, 0.2, 0. , 0.2, 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.09
#      longitude   float64 10.21
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U5 'Enga '
#      id          <U7 'SN27630'
#      name        <U17 'SANDEFJORD - ENGA',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0.8, 0.5, 1.7, 0. , 0. , 0. , 0. ])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 59.77
#      longitude   float64 10.01
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U11 'Langeløkka '
#      id          <U7 'SN26840'
#      name        <U25 'KROKSTADELVA - LANGELØKKA',
#  <xarray.DataArray 'PT1H' (time: 7)>
#  array([0. , 0. , 0.4, 0.2, 0. , 1. , 0.4])
#  Coordinates:
#    * time        (time) datetime64[ns] 2018-08-08T08:00:00 ... 2018-08-08T14:0...
#      latitude    float64 60.25
#      longitude   float64 12.09
#      resolution  <U30 'sum(precipitation_amount PT1H)'
#      shortname   <U7 'Roverud'
#      id          <U6 'SN5660'
#      name        <U7 'ROVERUD']
